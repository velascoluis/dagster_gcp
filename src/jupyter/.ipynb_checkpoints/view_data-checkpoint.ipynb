# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
gcs_uri = "/Users/velascoluis/PycharmProjects/dagster_gpu/src/data/stack_overflow000000000000.parquet"

# %%
df = pd.read_parquet(gcs_uri, engine='pyarrow')

# %%
df.plot(kind='bar',x='token',y='count',color='red')
plt.show()
